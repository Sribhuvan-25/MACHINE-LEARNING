# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading the csv file
heart = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
# Checking if there are any null value in the data set
heart.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
 heart.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
plt.figure(figsize=(12,8))
# Correlation between the features in the dataset
corr = heart.corr()
# Correlation Heatmap
import seaborn as sns
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
corr[abs(corr['DEATH_EVENT'])>0.1]['DEATH_EVENT']
# Out:
# age                  0.253729
# ejection_fraction   -0.268603
# serum_creatinine     0.294278
# serum_sodium        -0.195204
# time                -0.526964
# DEATH_EVENT          1.000000
# Name: DEATH_EVENT, dtype: float64

# %% [markdown]
# From the above table, it can be seen that the follwoing features have a considereble correlation with DEATH_EVENT

# %%
# Scatter plot (Age v/s Death_Event)
# plt.scatter(heart['age'],heart['DEATH_EVENT'],color='b')
# plt.xlabel('Age')
# plt.ylabel('DEATH_EVENT')

# %%
# Bargraph (Age v/s Death_Event)
# plt.bar(heart['age'],heart['DEATH_EVENT'])
# plt.xlabel('Age')
# plt.ylabel('DEATH_EVENT')

# %%
# Bargraph (Ejection_Fraction v/s Death_Event)
# plt.bar(heart['ejection_fraction'],heart['DEATH_EVENT'])
# plt.xlabel('ejection_fraction')
# plt.ylabel('DEATH_EVENT')

# %%
# Scatter plot (serum_creatinine  v/s Death_Event)
# plt.bar(heart['serum_creatinine'],heart['DEATH_EVENT'])
# plt.xlabel('serum_creatinine')
# plt.ylabel('DEATH_EVENT')

# %%
#Regression Model
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(X,y,test_size=0.2)
# Out:
#   File "<ipython-input-67-0935227380f1>", line 3
#     x_train, x_test, y_train,y_test = (X,y,test_size=0.2)
#                                                     ^
# SyntaxError: invalid syntax
