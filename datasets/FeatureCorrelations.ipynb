# %%
# !pip install -U yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in c:\users\sribhuvan\appdata\roaming\python\python39\site-packages (1.3.post1)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\sribhuvan\appdata\roaming\python\python39\site-packages (from yellowbrick) (0.10.0)
# Requirement already satisfied: numpy<1.20,>=1.16.0 in c:\users\sribhuvan\appdata\roaming\python\python39\site-packages (from yellowbrick) (1.19.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\sribhuvan\appdata\roaming\python\python39\site-packages (from yellowbrick) (3.4.2)
# Requirement already satisfied: scipy>=1.0.0 in d:\python\lib\site-packages (from yellowbrick) (1.6.3)
# Requirement already satisfied: scikit-learn>=0.20 in d:\python\lib\site-packages (from yellowbrick) (0.24.2)
# Requirement already satisfied: six in d:\python\lib\site-packages (from cycler>=0.10.0->yellowbrick) (1.16.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sribhuvan\appdata\roaming\python\python39\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sribhuvan\appdata\roaming\python\python39\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\python\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\python\lib\site-packages (from scikit-learn>=0.20->yellowbrick) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in d:\python\lib\site-packages (from scikit-learn>=0.20->yellowbrick) (1.0.1)
# WARNING: Ignoring invalid distribution -umpy (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\python\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (d:\python\lib\site-packages)
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the 'd:\python\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-71225e3ad40e> in <module>
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
diabetes = pd.read_csv('diabetes.csv')
diabetes.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
diabetes.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
#  Using the yellowbrick libaray to look at the correlations
X=diabetes[['Insulin','BMI','BloodPressure','DiabetesPedigreeFunction']]
Y=diabetes['Age']

# %%
feature_names = X.columns
feature_names
# Out:
# Index(['Insulin', 'BMI', 'BloodPressure', 'DiabetesPedigreeFunction'], dtype='object')

# %%
from yellowbrick.target import FeatureCorrelation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-67bbb99ff848> in <module>
# ----> 1 from yellowbrick.target import FeatureCorrelation
#
# ModuleNotFoundError: No module named 'yellowbrick'
